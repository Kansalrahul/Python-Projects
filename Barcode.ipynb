# %%
from barcode import EAN13

from barcode.writer import ImageWriter

number='591364164617'
    
my_code= EAN13( number ,writer=ImageWriter())

my_code.save ("new code 1")
# Out:
# 'new code 1.png'
